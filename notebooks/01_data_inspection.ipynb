# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd

# %%
pd.read_excel(
    "data/bq-heft-dlkaa-0-202506-xlsx.xlsx",
    sheet_name="kreise 2025"
)

import os
os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pd.read_excel(
#       2     "data/bq-heft-dlkaa-0-202506-xlsx.xlsx",
#       3     sheet_name="kreise 2025"
#       4 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
# ...

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\User\\Documents\\rhein_neckar_labour_market\\notebooks'

# %%
employ_df = pd.read_excel(
    "../data/bq-heft-dlkaa-0-202506-xlsx.xlsx",
    sheet_name="Kreise 2025",
    header=[6,7]
)

# %%
employ_df.head()
# Out:
#                          Region Bevölkerung1)                          \
#              Unnamed: 0_level_1     Insgesamt      Männer      Frauen
# 0                           NaN           1.0         2.0         3.0
# 1                   Deutschland    54121413.0  27460014.0  26661399.0
# 2         01 Schleswig-Holstein     1894310.0    949614.0    944696.0
# 3        01001 Flensburg, Stadt       65661.0     33329.0     32332.0
# 4  01002 Kiel, Landeshauptstadt      175369.0     87880.0     87489.0
#
#                          sozialversicherungspflichtig Beschäftigte2)  \
#      Deutsche Ausländer                                    Insgesamt
# 0         4.0        5.0                                         6.0
# 1  44512026.0  9609387.0                                  34230775.0
# 2   1662844.0   231466.0                                   1164849.0
# 3     52706.0    12955.0                                     35943.0
# ...

# %%
employ_df.head(15)
# Out:
#                                            Unnamed: 0     Unnamed: 1  \
# 0                                                 NaN            NaN
# 1   2. Bevölkerung, sozialversicherungspflichtig B...            NaN
# 2                  Deutschland nach Kreisen (Wohnort)            NaN
# 3                                Stichtag: 30.06.2025            NaN
# 4                                                 NaN            NaN
# 5                                              Region  Bevölkerung1)
# 6                                                 NaN      Insgesamt
# 7                                                 NaN              1
# 8                                         Deutschland       54121413
# 9                               01 Schleswig-Holstein        1894310
# 10                             01001 Flensburg, Stadt          65661
# 11                       01002 Kiel, Landeshauptstadt         175369
# 12                           01003 Lübeck, Hansestadt         141923
# ...

# %%
employ_df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Beschäftigungsstatistik'],
#       dtype='str')

# %%
employ_df.head(20)
# Out:
#                                            Unnamed: 0     Unnamed: 1  \
# 0                                                 NaN            NaN
# 1   2. Bevölkerung, sozialversicherungspflichtig B...            NaN
# 2                  Deutschland nach Kreisen (Wohnort)            NaN
# 3                                Stichtag: 30.06.2025            NaN
# 4                                                 NaN            NaN
# 5                                              Region  Bevölkerung1)
# 6                                                 NaN      Insgesamt
# 7                                                 NaN              1
# 8                                         Deutschland       54121413
# 9                               01 Schleswig-Holstein        1894310
# 10                             01001 Flensburg, Stadt          65661
# 11                       01002 Kiel, Landeshauptstadt         175369
# 12                           01003 Lübeck, Hansestadt         141923
# ...

# %%
employ_df.iloc[5:9]
# Out:
#     Unnamed: 0     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 5       Region  Bevölkerung1)        NaN        NaN        NaN         NaN
# 6          NaN      Insgesamt     Männer     Frauen   Deutsche  Ausländer
# 7          NaN              1          2          3          4           5
# 8  Deutschland       54121413   27460014   26661399   44512026     9609387
#
#                                     Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 5  sozialversicherungspflichtig Beschäftigte2)        NaN        NaN
# 6                                    Insgesamt     Männer     Frauen
# 7                                            6          7          8
# 8                                     34230775   18229401   16001374
#
#   Unnamed: 9 Unnamed: 10              Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 5        NaN         NaN  Beschäftigungsquoten3)          NaN         NaN
# 6   Deutsche   Ausländer                Insgesamt      Männer      Frauen
# ...

# %%
employ_df = employ_df.drop(0)

# %%
employ_df.head()
# Out:
#                          Region Bevölkerung1)                          \
#              Unnamed: 0_level_1     Insgesamt      Männer      Frauen
# 1                   Deutschland    54121413.0  27460014.0  26661399.0
# 2         01 Schleswig-Holstein     1894310.0    949614.0    944696.0
# 3        01001 Flensburg, Stadt       65661.0     33329.0     32332.0
# 4  01002 Kiel, Landeshauptstadt      175369.0     87880.0     87489.0
# 5      01003 Lübeck, Hansestadt      141923.0     70191.0     71732.0
#
#                          sozialversicherungspflichtig Beschäftigte2)  \
#      Deutsche Ausländer                                    Insgesamt
# 1  44512026.0  9609387.0                                  34230775.0
# 2   1662844.0   231466.0                                   1164849.0
# 3     52706.0    12955.0                                     35943.0
# 4    148429.0    26940.0                                     99416.0
# ...

# %%
employ_df = employ_df.reset_index(drop=True)

# %%
employ_df.columns
# Out:
# MultiIndex([(                                     'Region', ...),
#             (                              'Bevölkerung1)', ...),
#             (                              'Bevölkerung1)', ...),
#             (                              'Bevölkerung1)', ...),
#             (                              'Bevölkerung1)', ...),
#             (                              'Bevölkerung1)', ...),
#             ('sozialversicherungspflichtig Beschäftigte2)', ...),
#             ('sozialversicherungspflichtig Beschäftigte2)', ...),
#             ('sozialversicherungspflichtig Beschäftigte2)', ...),
#             ('sozialversicherungspflichtig Beschäftigte2)', ...),
#             ('sozialversicherungspflichtig Beschäftigte2)', ...),
#             (                    'Beschäftigungsquoten3) ', ...),
#             (                    'Beschäftigungsquoten3) ', ...),
#             (                    'Beschäftigungsquoten3) ', ...),
# ...

# %%
employ_df.columns[1]
# Out:
# ('Bevölkerung1)', 'Insgesamt')

# %%
employ_df.columns[6]
# Out:
# ('sozialversicherungspflichtig Beschäftigte2)', 'Insgesamt')

# %%
employ_df.columns[6][1]
# Out:
# 'Insgesamt'

# %%
employ_df.columns[6][0]+"_"+employ_df.columns[6][1]
# Out:
# 'sozialversicherungspflichtig Beschäftigte2)_Insgesamt'

# %%
for colonna in employ_df.columns:
    print(colonna[0]+"_"+colonna[1])
# Out:
# Region_Unnamed: 0_level_1
# Bevölkerung1)_Insgesamt
# Bevölkerung1)_Männer
# Bevölkerung1)_Frauen
# Bevölkerung1)_Deutsche
# Bevölkerung1)_Ausländer
# sozialversicherungspflichtig Beschäftigte2)_Insgesamt
# sozialversicherungspflichtig Beschäftigte2)_Männer
# sozialversicherungspflichtig Beschäftigte2)_Frauen
# sozialversicherungspflichtig Beschäftigte2)_Deutsche
# sozialversicherungspflichtig Beschäftigte2)_Ausländer
# Beschäftigungsquoten3) _Insgesamt
# Beschäftigungsquoten3) _Männer
# Beschäftigungsquoten3) _Frauen
# Beschäftigungsquoten3) _Deutsche
# Beschäftigungsquoten3) _Ausländer

# %%
nuove_colonne = []

for colonne in employ_df.columns:
    nuove_colonne.append(colonne[0]+"_"+colonne[1])

# %%
nuove_colonne
# Out:
# ['Region_Unnamed: 0_level_1',
#  'Bevölkerung1)_Insgesamt',
#  'Bevölkerung1)_Männer',
#  'Bevölkerung1)_Frauen',
#  'Bevölkerung1)_Deutsche',
#  'Bevölkerung1)_Ausländer ',
#  'sozialversicherungspflichtig Beschäftigte2)_Insgesamt',
#  'sozialversicherungspflichtig Beschäftigte2)_Männer',
#  'sozialversicherungspflichtig Beschäftigte2)_Frauen',
#  'sozialversicherungspflichtig Beschäftigte2)_Deutsche',
#  'sozialversicherungspflichtig Beschäftigte2)_Ausländer',
#  'Beschäftigungsquoten3) _Insgesamt',
#  'Beschäftigungsquoten3) _Männer',
#  'Beschäftigungsquoten3) _Frauen',
#  'Beschäftigungsquoten3) _Deutsche',
#  'Beschäftigungsquoten3) _Ausländer']

# %%
employ_df.columns = nuove_colonne

# %%
employ_df.head()
# Out:
#       Region_Unnamed: 0_level_1  Bevölkerung1)_Insgesamt  \
# 0                   Deutschland               54121413.0
# 1         01 Schleswig-Holstein                1894310.0
# 2        01001 Flensburg, Stadt                  65661.0
# 3  01002 Kiel, Landeshauptstadt                 175369.0
# 4      01003 Lübeck, Hansestadt                 141923.0
#
#    Bevölkerung1)_Männer  Bevölkerung1)_Frauen  Bevölkerung1)_Deutsche  \
# 0            27460014.0            26661399.0              44512026.0
# 1              949614.0              944696.0               1662844.0
# 2               33329.0               32332.0                 52706.0
# 3               87880.0               87489.0                148429.0
# 4               70191.0               71732.0                120136.0
#
#    Bevölkerung1)_Ausländer   \
# 0                 9609387.0
# 1                  231466.0
# 2                   12955.0
# 3                   26940.0
# 4                   21787.0
#
# ...

# %%
employ_df = employ_df.rename(
    columns={"Region_Unnamed: 0_level_1": "Region"}
)

# %%
employ_df.head(1)
# Out:
#         Region  Bevölkerung1)_Insgesamt  Bevölkerung1)_Männer  \
# 0  Deutschland               54121413.0            27460014.0
#
#    Bevölkerung1)_Frauen  Bevölkerung1)_Deutsche  Bevölkerung1)_Ausländer   \
# 0            26661399.0              44512026.0                 9609387.0
#
#    sozialversicherungspflichtig Beschäftigte2)_Insgesamt  \
# 0                                         34230775.0
#
#    sozialversicherungspflichtig Beschäftigte2)_Männer  \
# 0                                         18229401.0
#
#    sozialversicherungspflichtig Beschäftigte2)_Frauen  \
# 0                                         16001374.0
#
#    sozialversicherungspflichtig Beschäftigte2)_Deutsche  \
# 0                                         28650563.0
#
#    sozialversicherungspflichtig Beschäftigte2)_Ausländer  \
# 0                                          5580149.0
#
#    Beschäftigungsquoten3) _Insgesamt  Beschäftigungsquoten3) _Männer  \
# ...

# %%
nome = "Bevölkerung1)_Insgesamt"

nome.replace("1)", "")
# Out:
# 'Bevölkerung_Insgesamt'

# %%
for numero in ["1)", "2)", "3)"]:
    nome = nome.replace(numero, "")

# %%
employ_df.head(1)
# Out:
#         Region  Bevölkerung1)_Insgesamt  Bevölkerung1)_Männer  \
# 0  Deutschland               54121413.0            27460014.0
#
#    Bevölkerung1)_Frauen  Bevölkerung1)_Deutsche  Bevölkerung1)_Ausländer   \
# 0            26661399.0              44512026.0                 9609387.0
#
#    sozialversicherungspflichtig Beschäftigte2)_Insgesamt  \
# 0                                         34230775.0
#
#    sozialversicherungspflichtig Beschäftigte2)_Männer  \
# 0                                         18229401.0
#
#    sozialversicherungspflichtig Beschäftigte2)_Frauen  \
# 0                                         16001374.0
#
#    sozialversicherungspflichtig Beschäftigte2)_Deutsche  \
# 0                                         28650563.0
#
#    sozialversicherungspflichtig Beschäftigte2)_Ausländer  \
# 0                                          5580149.0
#
#    Beschäftigungsquoten3) _Insgesamt  Beschäftigungsquoten3) _Männer  \
# ...

# %%
for colonna in employ_df.columns:
    for numero in ["1)", "2)", "3)"]:
        colonna = colonna.replace(numero, "")

# %%
employ_df.head(1)
# Out:
#         Region  Bevölkerung1)_Insgesamt  Bevölkerung1)_Männer  \
# 0  Deutschland               54121413.0            27460014.0
#
#    Bevölkerung1)_Frauen  Bevölkerung1)_Deutsche  Bevölkerung1)_Ausländer   \
# 0            26661399.0              44512026.0                 9609387.0
#
#    sozialversicherungspflichtig Beschäftigte2)_Insgesamt  \
# 0                                         34230775.0
#
#    sozialversicherungspflichtig Beschäftigte2)_Männer  \
# 0                                         18229401.0
#
#    sozialversicherungspflichtig Beschäftigte2)_Frauen  \
# 0                                         16001374.0
#
#    sozialversicherungspflichtig Beschäftigte2)_Deutsche  \
# 0                                         28650563.0
#
#    sozialversicherungspflichtig Beschäftigte2)_Ausländer  \
# 0                                          5580149.0
#
#    Beschäftigungsquoten3) _Insgesamt  Beschäftigungsquoten3) _Männer  \
# ...

# %%
nuove_colonne
# Out:
# ['Region_Unnamed: 0_level_1',
#  'Bevölkerung1)_Insgesamt',
#  'Bevölkerung1)_Männer',
#  'Bevölkerung1)_Frauen',
#  'Bevölkerung1)_Deutsche',
#  'Bevölkerung1)_Ausländer ',
#  'sozialversicherungspflichtig Beschäftigte2)_Insgesamt',
#  'sozialversicherungspflichtig Beschäftigte2)_Männer',
#  'sozialversicherungspflichtig Beschäftigte2)_Frauen',
#  'sozialversicherungspflichtig Beschäftigte2)_Deutsche',
#  'sozialversicherungspflichtig Beschäftigte2)_Ausländer',
#  'Beschäftigungsquoten3) _Insgesamt',
#  'Beschäftigungsquoten3) _Männer',
#  'Beschäftigungsquoten3) _Frauen',
#  'Beschäftigungsquoten3) _Deutsche',
#  'Beschäftigungsquoten3) _Ausländer']

# %%
colonne_pulite = []

for colonna in employ_df.columns:
    for numero in ["1)", "2)", "3)"]:
        colonna = colonna.replace(numero, "")
    
    colonne_pulite.append(colonna)

colonne_pulite
# Out:
# ['Region',
#  'Bevölkerung_Insgesamt',
#  'Bevölkerung_Männer',
#  'Bevölkerung_Frauen',
#  'Bevölkerung_Deutsche',
#  'Bevölkerung_Ausländer ',
#  'sozialversicherungspflichtig Beschäftigte_Insgesamt',
#  'sozialversicherungspflichtig Beschäftigte_Männer',
#  'sozialversicherungspflichtig Beschäftigte_Frauen',
#  'sozialversicherungspflichtig Beschäftigte_Deutsche',
#  'sozialversicherungspflichtig Beschäftigte_Ausländer',
#  'Beschäftigungsquoten _Insgesamt',
#  'Beschäftigungsquoten _Männer',
#  'Beschäftigungsquoten _Frauen',
#  'Beschäftigungsquoten _Deutsche',
#  'Beschäftigungsquoten _Ausländer']

# %%
employ_df.columns = colonne_pulite

# %%
employ_df.head(1)
# Out:
#         Region  Bevölkerung_Insgesamt  Bevölkerung_Männer  Bevölkerung_Frauen  \
# 0  Deutschland             54121413.0          27460014.0          26661399.0
#
#    Bevölkerung_Deutsche  Bevölkerung_Ausländer   \
# 0            44512026.0               9609387.0
#
#    sozialversicherungspflichtig Beschäftigte_Insgesamt  \
# 0                                         34230775.0
#
#    sozialversicherungspflichtig Beschäftigte_Männer  \
# 0                                        18229401.0
#
#    sozialversicherungspflichtig Beschäftigte_Frauen  \
# 0                                        16001374.0
#
#    sozialversicherungspflichtig Beschäftigte_Deutsche  \
# 0                                         28650563.0
#
#    sozialversicherungspflichtig Beschäftigte_Ausländer  \
# 0                                          5580149.0
#
#    Beschäftigungsquoten _Insgesamt  Beschäftigungsquoten _Männer  \
# 0                        63.248118                     66.385257
#
# ...

# %%
employ_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 422 entries, 0 to 421
# Data columns (total 16 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Region                                               421 non-null    str
#  1   Bevölkerung_Insgesamt                                417 non-null    float64
#  2   Bevölkerung_Männer                                   417 non-null    float64
#  3   Bevölkerung_Frauen                                   417 non-null    float64
#  4   Bevölkerung_Deutsche                                 417 non-null    float64
#  5   Bevölkerung_Ausländer                                417 non-null    float64
#  6   sozialversicherungspflichtig Beschäftigte_Insgesamt  417 non-null    float64
#  7   sozialversicherungspflichtig Beschäftigte_Männer     417 non-null    float64
# ...

# %%
employ_df[
    employ_df["Bevölkerung_Insgesamt"].isnull()
]
# Out:
#                                                 Region  Bevölkerung_Insgesamt  \
# 417                                                NaN                    NaN
# 418  1) Quelle: Statistisches Bundesamt - Bevölkeru...                    NaN
# 419  2) Sozialversicherungspflichtig Beschäftigte i...                    NaN
# 420                                    Methodenbericht                    NaN
# 421  3) Die Beschäftigungsquote (SvB) gibt den Ante...                    NaN
#
#      Bevölkerung_Männer  Bevölkerung_Frauen  Bevölkerung_Deutsche  \
# 417                 NaN                 NaN                   NaN
# 418                 NaN                 NaN                   NaN
# 419                 NaN                 NaN                   NaN
# 420                 NaN                 NaN                   NaN
# 421                 NaN                 NaN                   NaN
#
#      Bevölkerung_Ausländer   \
# 417                     NaN
# 418                     NaN
# ...

# %%
employ_df = employ_df.drop(range(417, 422))

# %%
employ_df.tail(5)
# Out:
#                          Region  Bevölkerung_Insgesamt  Bevölkerung_Männer  \
# 412   16073 Saalfeld-Rudolstadt                58772.0             30659.0
# 413  16074 Saale-Holzland-Kreis                50336.0             26042.0
# 414      16075 Saale-Orla-Kreis                46295.0             24154.0
# 415                 16076 Greiz                54024.0             28089.0
# 416      16077 Altenburger Land                50587.0             26004.0
#
#      Bevölkerung_Frauen  Bevölkerung_Deutsche  Bevölkerung_Ausländer   \
# 412             28113.0               54550.0                  4222.0
# 413             24294.0               46540.0                  3796.0
# 414             22141.0               42832.0                  3463.0
# 415             25935.0               50623.0                  3401.0
# 416             24583.0               45484.0                  5103.0
#
#      sozialversicherungspflichtig Beschäftigte_Insgesamt  \
# ...

# %%
employ_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 417 entries, 0 to 416
# Data columns (total 16 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Region                                               417 non-null    str
#  1   Bevölkerung_Insgesamt                                417 non-null    float64
#  2   Bevölkerung_Männer                                   417 non-null    float64
#  3   Bevölkerung_Frauen                                   417 non-null    float64
#  4   Bevölkerung_Deutsche                                 417 non-null    float64
#  5   Bevölkerung_Ausländer                                417 non-null    float64
#  6   sozialversicherungspflichtig Beschäftigte_Insgesamt  417 non-null    float64
#  7   sozialversicherungspflichtig Beschäftigte_Männer     417 non-null    float64
# ...

# %%
employ_df["Region"].str.contains("Ludwigshafen")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 412    False
# 413    False
# 414    False
# 415    False
# 416    False
# Name: Region, Length: 417, dtype: bool

# %%
dat_lu = employ_df[
    employ_df["Region"].str.contains("Ludwigshafen")
]

# %%
dat_lu
# Out:
#                                             Region  Bevölkerung_Insgesamt  \
# 169  07314 Ludwigshafen am Rhein, kreisfreie Stadt               118031.0
#
#      Bevölkerung_Männer  Bevölkerung_Frauen  Bevölkerung_Deutsche  \
# 169             62100.0             55931.0               75170.0
#
#      Bevölkerung_Ausländer   \
# 169                 42861.0
#
#      sozialversicherungspflichtig Beschäftigte_Insgesamt  \
# 169                                            70932.0
#
#      sozialversicherungspflichtig Beschäftigte_Männer  \
# 169                                           41000.0
#
#      sozialversicherungspflichtig Beschäftigte_Frauen  \
# 169                                           29932.0
#
#      sozialversicherungspflichtig Beschäftigte_Deutsche  \
# 169                                            47222.0
#
#      sozialversicherungspflichtig Beschäftigte_Ausländer  \
# 169                                            23710.0
#
# ...

# %%
dat_ma = employ_df[employ_df["Region"].str.contains("Mannheim")]

# %%
dat_ma
# Out:
#                                 Region  Bevölkerung_Insgesamt  \
# 205  08222 Mannheim, Universitätsstadt               220816.0
#
#      Bevölkerung_Männer  Bevölkerung_Frauen  Bevölkerung_Deutsche  \
# 205            113575.0            107241.0              150560.0
#
#      Bevölkerung_Ausländer   \
# 205                 70256.0
#
#      sozialversicherungspflichtig Beschäftigte_Insgesamt  \
# 205                                           136258.0
#
#      sozialversicherungspflichtig Beschäftigte_Männer  \
# 205                                           74621.0
#
#      sozialversicherungspflichtig Beschäftigte_Frauen  \
# 205                                           61637.0
#
#      sozialversicherungspflichtig Beschäftigte_Deutsche  \
# 205                                            97918.0
#
#      sozialversicherungspflichtig Beschäftigte_Ausländer  \
# 205                                            38340.0
#
# ...

# %%
dat_hd = employ_df[employ_df["Region"].str.contains("Heidelberg")]
dat_hd
# Out:
#                       Region  Bevölkerung_Insgesamt  Bevölkerung_Männer  \
# 204  08221 Heidelberg, Stadt               112254.0             54271.0
#
#      Bevölkerung_Frauen  Bevölkerung_Deutsche  Bevölkerung_Ausländer   \
# 204             57983.0               83762.0                 28492.0
#
#      sozialversicherungspflichtig Beschäftigte_Insgesamt  \
# 204                                            58119.0
#
#      sozialversicherungspflichtig Beschäftigte_Männer  \
# 204                                           29349.0
#
#      sozialversicherungspflichtig Beschäftigte_Frauen  \
# 204                                           28770.0
#
#      sozialversicherungspflichtig Beschäftigte_Deutsche  \
# 204                                            43772.0
#
#      sozialversicherungspflichtig Beschäftigte_Ausländer  \
# 204                                            14347.0
#
#      Beschäftigungsquoten _Insgesamt  Beschäftigungsquoten _Männer  \
# ...

# %%
dat_sp = employ_df[employ_df["Region"].str.contains("Speyer")]
dat_sp
# Out:
#                              Region  Bevölkerung_Insgesamt  \
# 173  07318 Speyer, kreisfreie Stadt                31572.0
#
#      Bevölkerung_Männer  Bevölkerung_Frauen  Bevölkerung_Deutsche  \
# 173             15891.0             15681.0               25022.0
#
#      Bevölkerung_Ausländer   \
# 173                  6550.0
#
#      sozialversicherungspflichtig Beschäftigte_Insgesamt  \
# 173                                            19807.0
#
#      sozialversicherungspflichtig Beschäftigte_Männer  \
# 173                                           10412.0
#
#      sozialversicherungspflichtig Beschäftigte_Frauen  \
# 173                                            9395.0
#
#      sozialversicherungspflichtig Beschäftigte_Deutsche  \
# 173                                            15991.0
#
#      sozialversicherungspflichtig Beschäftigte_Ausländer  \
# 173                                             3816.0
#
# ...

# %%
dat_ft = employ_df[employ_df["Region"].str.contains("Frankenthal")]
dat_ft
# Out:
#                                           Region  Bevölkerung_Insgesamt  \
# 166  07311 Frankenthal (Pfalz), kreisfreie Stadt                30311.0
#
#      Bevölkerung_Männer  Bevölkerung_Frauen  Bevölkerung_Deutsche  \
# 166             15745.0             14566.0               22243.0
#
#      Bevölkerung_Ausländer   \
# 166                  8068.0
#
#      sozialversicherungspflichtig Beschäftigte_Insgesamt  \
# 166                                            17483.0
#
#      sozialversicherungspflichtig Beschäftigte_Männer  \
# 166                                            9872.0
#
#      sozialversicherungspflichtig Beschäftigte_Frauen  \
# 166                                            7611.0
#
#      sozialversicherungspflichtig Beschäftigte_Deutsche  \
# 166                                            13138.0
#
#      sozialversicherungspflichtig Beschäftigte_Ausländer  \
# 166                                             4345.0
#
# ...

# %%
dat_citta = pd.concat([dat_lu, dat_hd, dat_ma, dat_sp, dat_ft])
dat_citta
# Out:
#                                             Region  Bevölkerung_Insgesamt  \
# 169  07314 Ludwigshafen am Rhein, kreisfreie Stadt               118031.0
# 204                        08221 Heidelberg, Stadt               112254.0
# 205              08222 Mannheim, Universitätsstadt               220816.0
# 173                 07318 Speyer, kreisfreie Stadt                31572.0
# 166    07311 Frankenthal (Pfalz), kreisfreie Stadt                30311.0
#
#      Bevölkerung_Männer  Bevölkerung_Frauen  Bevölkerung_Deutsche  \
# 169             62100.0             55931.0               75170.0
# 204             54271.0             57983.0               83762.0
# 205            113575.0            107241.0              150560.0
# 173             15891.0             15681.0               25022.0
# 166             15745.0             14566.0               22243.0
#
#      Bevölkerung_Ausländer   \
# 169                 42861.0
# 204                 28492.0
# 205                 70256.0
# ...

# %%
dat_citta = dat_citta.reset_index(drop=True)
dat_citta
# Out:
#                                           Region  Bevölkerung_Insgesamt  \
# 0  07314 Ludwigshafen am Rhein, kreisfreie Stadt               118031.0
# 1                        08221 Heidelberg, Stadt               112254.0
# 2              08222 Mannheim, Universitätsstadt               220816.0
# 3                 07318 Speyer, kreisfreie Stadt                31572.0
# 4    07311 Frankenthal (Pfalz), kreisfreie Stadt                30311.0
#
#    Bevölkerung_Männer  Bevölkerung_Frauen  Bevölkerung_Deutsche  \
# 0             62100.0             55931.0               75170.0
# 1             54271.0             57983.0               83762.0
# 2            113575.0            107241.0              150560.0
# 3             15891.0             15681.0               25022.0
# 4             15745.0             14566.0               22243.0
#
#    Bevölkerung_Ausländer   \
# 0                 42861.0
# 1                 28492.0
# 2                 70256.0
# 3                  6550.0
# ...

# %%
dat_citta["Region"] = dat_citta["Region"].replace({
    "07314 Ludwigshafen am Rhein, kreisfreie Stadt": "Ludwigshafen",
    "08221 Heidelberg, Stadt": "Heidelberg",
    "08222 Mannheim, Universitätsstadt": "Mannheim",
    "07318 Speyer, kreisfreie Stadt": "Speyer",
    "07311 Frankenthal (Pfalz), kreisfreie Stadt": "Frankenthal"
})

dat_citta
# Out:
#          Region  Bevölkerung_Insgesamt  Bevölkerung_Männer  \
# 0  Ludwigshafen               118031.0             62100.0
# 1    Heidelberg               112254.0             54271.0
# 2      Mannheim               220816.0            113575.0
# 3        Speyer                31572.0             15891.0
# 4   Frankenthal                30311.0             15745.0
#
#    Bevölkerung_Frauen  Bevölkerung_Deutsche  Bevölkerung_Ausländer   \
# 0             55931.0               75170.0                 42861.0
# 1             57983.0               83762.0                 28492.0
# 2            107241.0              150560.0                 70256.0
# 3             15681.0               25022.0                  6550.0
# 4             14566.0               22243.0                  8068.0
#
#    sozialversicherungspflichtig Beschäftigte_Insgesamt  \
# 0                                            70932.0
# 1                                            58119.0
# ...

# %%
dat_citta.columns
# Out:
# Index(['Region', 'Bevölkerung_Insgesamt', 'Bevölkerung_Männer',
#        'Bevölkerung_Frauen', 'Bevölkerung_Deutsche', 'Bevölkerung_Ausländer ',
#        'sozialversicherungspflichtig Beschäftigte_Insgesamt',
#        'sozialversicherungspflichtig Beschäftigte_Männer',
#        'sozialversicherungspflichtig Beschäftigte_Frauen',
#        'sozialversicherungspflichtig Beschäftigte_Deutsche',
#        'sozialversicherungspflichtig Beschäftigte_Ausländer',
#        'Beschäftigungsquoten _Insgesamt', 'Beschäftigungsquoten _Männer',
#        'Beschäftigungsquoten _Frauen', 'Beschäftigungsquoten _Deutsche',
#        'Beschäftigungsquoten _Ausländer'],
#       dtype='str')

# %%
occupazione_citta = dat_citta[["Region", "Beschäftigungsquoten _Insgesamt"]]
occupazione_citta
# Out:
#          Region  Beschäftigungsquoten _Insgesamt
# 0  Ludwigshafen                        60.096076
# 1    Heidelberg                        51.774547
# 2      Mannheim                        61.706579
# 3        Speyer                        62.735969
# 4   Frankenthal                        57.678730

# %%
occupazione_citta = occupazione_citta.sort_values(
    "Beschäftigungsquoten _Insgesamt",
    ascending=False
)

occupazione_citta
# Out:
#          Region  Beschäftigungsquoten _Insgesamt
# 3        Speyer                        62.735969
# 2      Mannheim                        61.706579
# 0  Ludwigshafen                        60.096076
# 4   Frankenthal                        57.678730
# 1    Heidelberg                        51.774547

# %%
occupazione_citta.reset_index(drop=True)
# Out:
#          Region  Beschäftigungsquoten _Insgesamt
# 0        Speyer                        62.735969
# 1      Mannheim                        61.706579
# 2  Ludwigshafen                        60.096076
# 3   Frankenthal                        57.678730
# 4    Heidelberg                        51.774547

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
plt.bar(
    occupazione_citta["Region"],
    occupazione_citta["Beschäftigungsquoten _Insgesamt"]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 plt.bar(
#       2     occupazione_citta["Region"],
#       3     occupazione_citta["Beschäftigungsquoten _Insgesamt"]
#       4 )
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.bar(
        occupazione_citta["Region"],
        occupazione_citta["Beschäftigungsquoten _Insgesamt"]
       )
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize=(10, 6))

barre = plt.bar(
    occupazione_citta["Region"],
    occupazione_citta["Beschäftigungsquoten _Insgesamt"]
)

plt.title("Employment Rate by City – Rhein-Neckar Region")
plt.ylabel("Employment Rate (%)")
plt.bar_label(barre, fmt="%.2f%%")
# Out:
# [Text(0, 0, '62.74%'),
#  Text(0, 0, '61.71%'),
#  Text(0, 0, '60.10%'),
#  Text(0, 0, '57.68%'),
#  Text(0, 0, '51.77%')]
